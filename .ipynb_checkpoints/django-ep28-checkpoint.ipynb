# %%
url = "http://www.earlyadopter.co.kr/wp-content/uploads/2017/01/LINE-FRIENDS-USB-HUMIDIFIER_-18.jpg"

# %%
import requests

image_binary = request.get(url).content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b232293c370c> in <module>()
#       1 import requests
#       2
# ----> 3 image_binary = request.get(url).content
#
# NameError: name 'request' is not defined

# %%
import request
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-e392607f0c42> in <module>()
# ----> 1 import request
#
# ModuleNotFoundError: No module named 'request'

# %%
import requests

# %%
image_binary = requests.get(url).content

with open('image.jpg', "wb") as f:
    f.write(image_binary)

# %%
from PIL import Image

# %%
image = Image.open("image.jpg")

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1300x868 at 0x13C7710>

# %%
from pilkit.processors import Thumbnail

# %%
processor = Thumbnail(width=300, height=300)

# %%
thum_image = processor.process(image)

# %%
thum_image
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x6C7A630>

# %%
thum_image.save("thumb-300x300.png")
for quality in [100,80,60,40,20]:
    thum_image.save("thumb-300x300-{}.jpg".format(quality), quality=quality)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\program files (x86)\python36-32\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     620     try:
# --> 621         rawmode = RAWMODE[im.mode]
#     622     except KeyError:
#
# KeyError: 'RGBA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-afd3fd83208e> in <module>()
#       1 thum_image.save("thumb-300x300.png")
#       2 for quality in [100,80,60,40,20]:
# ----> 3     thum_image.save("thumb-300x300-{}.jpg".format(quality), quality=quality)
#       4
#       5
#
# c:\program files (x86)\python36-32\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    1948
#    1949         try:
# -> 1950             save_handler(self, fp, filename)
#    1951         finally:
# ...
